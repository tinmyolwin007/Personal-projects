# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('supermarket_sales - Sheet1.csv',parse_dates=['Date'])

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675  1/29/2019  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900   3/2/2019  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320   2/9/2019  13:22     Cash
# 998       65.82         1   3.2910    69.1110  2/22/2019  15:33     Cash
# 999       88.34         7  30.9190   649.2990  2/18/2019  13:28     Cash
#
# ...

# %%
df.sample(5)
# Out:
#       Invoice ID Branch      City Customer type  Gender         Product line  \
# 883  291-55-6563      A    Yangon        Member  Female   Home and lifestyle
# 212  142-63-6033      B  Mandalay        Normal    Male   Home and lifestyle
# 657  562-12-5430      A    Yangon        Member  Female  Fashion accessories
# 952  574-80-1489      B  Mandalay        Member  Female   Food and beverages
# 294  585-03-5943      B  Mandalay        Normal    Male    Health and beauty
#
#      Unit price  Quantity   Tax 5%     Total       Date   Time  Payment  \
# 883       34.42         6  10.3260  216.8460  3/30/2019  12:45  Ewallet
# 212       92.36         5  23.0900  484.8900  3/20/2019  19:17  Ewallet
# 657       88.15         3  13.2225  277.6725  1/18/2019  10:11  Ewallet
# 952       62.85         4  12.5700  263.9700  2/25/2019  13:22  Ewallet
# 294       18.11        10   9.0550  190.1550  3/13/2019  11:46  Ewallet
#
#        cogs  gross margin percentage  gross income  Rating
# ...

# %%
df.shape
# Out:
# (1000, 17)

# %%
print("Number of Columns",df.shape[1])
print("Number of Rows",df.shape[0])
# Out:
# Number of Columns 17
# Number of Rows 1000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
cat=[]
num=[]
for column in df.columns:
    if df[column].nunique()>10:
        num.append(column)
    else:
        cat.append(column)

# %%
cat
# Out:
# ['Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Quantity',
#  'Payment',
#  'gross margin percentage']

# %%
num
# Out:
# ['Invoice ID',
#  'Unit price',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'cogs',
#  'gross income',
#  'Rating']

# %% [markdown]
# # Find aggregate sales among branches

# %%
sns.countplot(x='Branch',data=df)
plt.title("Sales Among Branches ")
plt.show()

# %%
df['Branch'].value_counts().plot(kind='pie',autopct='%1.2f%%')
# Out:
# <Axes: ylabel='Branch'>

# %%
df['Branch'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %% [markdown]
# # Find the most popular payment method used by customers

# %%
sns.countplot(x='Payment', data=df)
plt.title("Most Popular Payment Method")
plt.show()

# %%
df['Payment'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %% [markdown]
# # Find the Distribution of Customer Ratings

# %%
sns.histplot(
    df["Rating"], kde=True,
    stat="density", kde_kws=dict(cut=3)
)
plt.title("Distribution of Customer Ratings")
plt.show()

# %%
df['Rating'].skew()
# Out:
# 0.00900964876573073

# %% [markdown]
# # Find the Distribution of Cost of Goods Sold

# %%
sns.histplot(
    df["cogs"], kde=True,
    stat="density", kde_kws=dict(cut=3)
)
plt.title('Distribution of Cost of Goods Sold')
plt.show()

# %%
df['cogs'].skew()
# Out:
# 0.8925698049581418

# %%
sns.boxplot(df['cogs'])
# Out:
# <Axes: >

# %% [markdown]
# # Does the Cost of Goods Sold affect the Ratings

# %%
cat
# Out:
# ['Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Quantity',
#  'Payment',
#  'gross margin percentage']

# %%
num
# Out:
# ['Invoice ID',
#  'Unit price',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'cogs',
#  'gross income',
#  'Rating']

# %%
sns.scatterplot(x='cogs',y='Rating',data=df)
plt.title('Cost of Goods Sold vs Ratings')
plt.show()

# %% [markdown]
# # Does Gross Income Affect the Ratings

# %%
sns.scatterplot(x='gross income',y='Rating',data=df)
plt.title("Gross Income vs Ratings")
plt.show()

# %% [markdown]
# # The Most Profitable Branch per Gross Income

# %%
cat
# Out:
# ['Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Quantity',
#  'Payment',
#  'gross margin percentage']

# %%
num
# Out:
# ['Invoice ID',
#  'Unit price',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'cogs',
#  'gross income',
#  'Rating']

# %%
sns.barplot(x='Branch',y='gross income',data=df)
plt.title('Most Profitable Branch Per Gross Income')
plt.show()

# %%
sns.barplot(x='Branch',y='gross income',data=df,hue='City')
plt.title('Most Profitable Branch Per Gross Income by City')
plt.show()

# %% [markdown]
# # Relationship Between Gender and Gross Income

# %%
sns.boxplot(x='Gender',y='gross income',data=df)
plt.title('Relationship Between Gender and Gross Income')
plt.show()

# %%
sns.boxplot(x='Gender',y='gross income',data=df,hue='Customer type')
plt.title('Relationship Between Gender and Gross Income by Customer Type')
plt.show()

# %% [markdown]
# # Find the Product Line that Generates the most Income

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
sns.barplot(x='Product line', y='gross income',data=df)
plt.xticks(rotation=80)
plt.title('The Most Income Product Line')
plt.show()

# %% [markdown]
# # Find the Highest Unit Price in the Product Line

# %%
sns.barplot(x='Product line', y='Unit price',data=df)
plt.xticks(rotation=80)
plt.title('Product Line of Unit Price')
plt.show()

# %% [markdown]
# # Find Different Payment Methods used by Customer Citywise

# %%
cat
# Out:
# ['Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Quantity',
#  'Payment',
#  'gross margin percentage']

# %%
num
# Out:
# ['Invoice ID',
#  'Unit price',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'cogs',
#  'gross income',
#  'Rating']

# %%
pd.crosstab(df['City'],df['Payment'])
# Out:
# Payment    Cash  Credit card  Ewallet
# City
# Mandalay    110          109      113
# Naypyitaw   124           98      106
# Yangon      110          104      126

# %%
sns.heatmap(pd.crosstab(df['City'],df['Payment']))
plt.title('Different Payments Methods used by Customer Citywise')
plt.show()

# %% [markdown]
# # Which Product Line is Purchased in the Highest Quantity

# %%
df.groupby('Product line').sum()['Quantity']
# Out:
# C:\Users\UI UX 2\AppData\Local\Temp\ipykernel_1356\782012844.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Product line').sum()['Quantity']
# Product line
# Electronic accessories    971
# Fashion accessories       902
# Food and beverages        952
# Health and beauty         854
# Home and lifestyle        911
# Sports and travel         920
# Name: Quantity, dtype: int64

# %%
(df.groupby('Product line').sum()['Quantity']).plot(kind='bar')
# Out:
# C:\Users\UI UX 2\AppData\Local\Temp\ipykernel_1356\1903985707.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   (df.groupby('Product line').sum()['Quantity']).plot(kind='bar')
# <Axes: xlabel='Product line'>

# %% [markdown]
# # Display Daily Sales by Day of the week

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
dw_mapping={
    0:'Mon',
    1:'Tue',
    2:'Wed',
    3:'Thur',
    4:'Fri',
    5:'Sat',
    6:'Sun'
}

# %%
df['Day_of_week'] = df['Date'].dt.dayofweek.map(dw_mapping)

# %%
df['Day_of_week']
# Out:
# 0      Sat
# 1      Fri
# 2      Sun
# 3      Sun
# 4      Fri
#       ...
# 995    Tue
# 996    Sat
# 997    Sat
# 998    Fri
# 999    Mon
# Name: Day_of_week, Length: 1000, dtype: object

# %%
df['Day_of_week'].value_counts()
# Out:
# Sat     164
# Tue     158
# Wed     143
# Fri     139
# Thur    138
# Sun     133
# Mon     125
# Name: Day_of_week, dtype: int64

# %%
df['Day_of_week'].value_counts().plot(kind='bar')
plt.title('Daily Sales by Day of the week')
plt.show()

# %%
df.head(1)
# Out:
#     Invoice ID Branch    City Customer type  Gender       Product line  \
# 0  750-67-8428      A  Yangon        Member  Female  Health and beauty
#
#    Unit price  Quantity   Tax 5%     Total       Date   Time  Payment    cogs  \
# 0       74.69         7  26.1415  548.9715 2019-01-05  13:08  Ewallet  522.83
#
#    gross margin percentage  gross income  Rating Day_of_week
# 0                 4.761905       26.1415     9.1         Sat

# %% [markdown]
# # What will be the Highest Months for Sales

# %%
month_mapping = {
    1:'Jan',
    2:'Feb',
    3:'March'
}

# %%
df['Month'] = df['Date'].dt.month.map(month_mapping)

# %%
df['Month']
# Out:
# 0        Jan
# 1      March
# 2      March
# 3        Jan
# 4        Feb
#        ...
# 995      Jan
# 996    March
# 997      Feb
# 998      Feb
# 999      Feb
# Name: Month, Length: 1000, dtype: object

# %%
df.head(1)
# Out:
#     Invoice ID Branch    City Customer type  Gender       Product line  \
# 0  750-67-8428      A  Yangon        Member  Female  Health and beauty
#
#    Unit price  Quantity   Tax 5%     Total       Date   Time  Payment    cogs  \
# 0       74.69         7  26.1415  548.9715 2019-01-05  13:08  Ewallet  522.83
#
#    gross margin percentage  gross income  Rating Day_of_week Month
# 0                 4.761905       26.1415     9.1         Sat   Jan

# %%
df['Month'].value_counts().plot(kind='bar')
plt.title('Monthly Sales')
plt.show()
